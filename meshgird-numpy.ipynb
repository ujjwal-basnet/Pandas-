# %%
import numpy as np 
x = np.linspace(-1 , 1 , 10)

# %%
x.shape
# Out:
# (10,)

# %%
#putting into sign function
f = np.sin(x)

# %%
import  matplotlib.pyplot as plt 
#plotting y grid 
fig , (ax1 , ax2) = plt.subplots(1 ,2 , figsize = (12 , 5 )) 

ax1.plot(f , marker = '.' , markersize = 30  )
#plotting x  grid 
ax2.plot(x , marker = '.' , markersize = 30 , c = 'red')

# %% [markdown]
# ## but what if were are working with 2-d ?

# %% [markdown]
# ## for 1-d you calculate sin(x)
# ## for 2-d you have to calculate sin(x ,y ) that is sinx . cosy how would you calculte this ?

# %%
x = np.linspace(-1 , 1  , 10 )
y  = np.linspace(-1 , 1 , 10 )

# %%
x == y  #both x and y are equal
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# ### you could write " sin(x) * cos(y) inorder to calculate sin(x  ,y )

# %%
np.sin(x) * np.cos(y)
# Out:
# array([-0.45464871, -0.49994193, -0.4480961 , -0.3091849 , -0.11019887,
#         0.11019887,  0.3091849 ,  0.4480961 ,  0.49994193,  0.45464871])

# %% [markdown]
# ### but stil what you have got is in 1 -d array

# %%
(np.sin(x) * np.cos(y)).shape
# Out:
# (10,)

# %% [markdown]
# ## Thats where meshgid comes in

# %%
X  , y  = np.meshgrid(x , y )

# %%
X.shape
# Out:
# (10, 10)

# %%
fig ,  ( ax1 , ax2 ) = plt.subplots(1 ,2 , figsize = (12 , 5 ) )
ax1.scatter(X , y)
ax2.plot(X , y)
plt.show()

#grid plot
